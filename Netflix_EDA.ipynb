# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishna3226/netflix-data-analysis/blob/main/Netflix_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Netflix Movies and TV Shows: An Exploratory Data Analysis. In this notebook, I will explore the Netflix dataset to understand content trends, popular genres, and the distribution of content across the globe.**

# %% [markdown]
# #  Netflix Exploratory Data Analysis (EDA) – Updated till 2025
#
# ## 🔹 Introduction
# Netflix is one of the largest streaming platforms, offering thousands of Movies and TV Shows globally.
# This project analyzes Netflix data till **2025**, providing more updated insights than traditional 2021 datasets.
#
# ## 🔹 Objectives
# - Clean and preprocess the dataset
# - Explore patterns in Movies vs TV Shows
# - Analyze trends across countries and years
# - Study popular genres and ratings
# - Derive insights on how Netflix’s strategy evolved till 2025

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 🔹 Dataset Description
# We have two separate CSV files:
# - **Movies dataset**
# - **TV Shows dataset**
#
# Each dataset includes:
# - `title` – Name of the content
# - `director`, `cast` – Key people involved
# - `country` – Origin country
# - `release_year` – Original release year
# - `date_added` – When added to Netflix
# - `rating` – Age rating (PG, R, TV-MA, etc.)
# - `duration` – Runtime (Movies) or Seasons (TV Shows)
# - `listed_in` – Genres
# - `description` – Short summary

# %%
#Importing Necessary Libararies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Style for plots
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# Load the Netflix dataset
movies = pd.read_csv("/content/drive/MyDrive/1230280501028 (1)/Projects/Netflix_Analysis/netflix_movies_detailed_up_to_2025.csv")
tv_shows=pd.read_csv("/content/drive/MyDrive/1230280501028 (1)/Projects/Netflix_Analysis/netflix_tv_shows_detailed_up_to_2025.csv")

df=pd.concat([movies,tv_shows],axis=0)
df.columns
print("Shape of Dataset: ",df.shape)
df
# Out:
# Shape of Dataset:  (32000, 18)
#        show_id     type                                         title  \
# 0        10192    Movie                           Shrek Forever After
# 1        27205    Movie                                     Inception
# 2        12444    Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757    Movie                                       Tangled
# 4        10191    Movie                      How to Train Your Dragon
# ...        ...      ...                                           ...
# 15995   284892  TV Show                                    Sammelanam
# 15996   277665  TV Show                                  Anne Shirley
# 15997   284972  TV Show                           Le onde del passato
# 15998   284613  TV Show                                       AI히치하이커
# 15999   251815  TV Show        Alex & Laura's Saturday Night Takeaway
#
#                           director  \
# 0                    Mike Mitchell
# 1                Christopher Nolan
# 2                      David Yates
# 3       Byron Howard, Nathan Greno
# 4      Chris Sanders, Dean DeBlois
# ...                            ...
# 15995                          NaN
# 15996                          NaN
# 15997           Giulio Manfredonia
# 15998                          NaN
# 15999                          NaN
#
#                                                     cast  \
# 0      Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1      Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2      Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3      Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4      Jay Baruchel, Gerard Butler, Craig Ferguson, A...
# ...                                                  ...
# 15995                                                NaN
# 15996  Honoka Inoue, Yasunori Matsumoto, Aya Nakamura...
# 15997  Anna Valle, Giorgio Marchesi, Irene Ferri, Fau...
# 15998                                                NaN
# 15999                       Alex Bickerton, Lauren Blake
#
#                                         country  date_added  release_year  \
# 0                      United States of America  2010-05-16          2010
# 1      United Kingdom, United States of America  2010-07-15          2010
# 2      United Kingdom, United States of America  2010-11-17          2010
# 3                      United States of America  2010-11-24          2010
# 4                      United States of America  2010-03-18          2010
# ...                                         ...         ...           ...
# 15995                                       NaN  2025-02-20          2025
# 15996                                     Japan  2025-04-05          2025
# 15997                                       NaN  2025-02-19          2025
# 15998                                       NaN  2025-02-16          2025
# 15999                                       NaN  2025-02-15          2025
#
#        rating   duration                                         genres  \
# 0       6.380        NaN  Comedy, Adventure, Fantasy, Animation, Family
# 1       8.369        NaN             Action, Science Fiction, Adventure
# 2       7.744        NaN                             Adventure, Fantasy
# 3       7.600        NaN                   Animation, Family, Adventure
# 4       7.800        NaN          Fantasy, Adventure, Animation, Family
# ...       ...        ...                                            ...
# 15995   0.000  1 Seasons                                  Comedy, Drama
# 15996   0.000  1 Seasons                       Animation, Drama, Family
# 15997  10.000  1 Seasons                                          Drama
# 15998   0.000  1 Seasons                                            NaN
# 15999   0.000  1 Seasons                                 Comedy, Family
#
#       language                                        description  popularity  \
# 0           en  A bored and domesticated Shrek pacts with deal...     203.893
# 1           en  Cobb, a skilled thief who commits corporate es...     156.242
# 2           en  Harry, Ron and Hermione walk away from their l...     121.191
# 3           en  Feisty teenager Rapunzel, who has long and mag...     111.762
# 4           en  As the son of a Viking leader on the cusp of m...     110.044
# ...        ...                                                ...         ...
# 15995       te  Sammelanam is a gripping Telugu web series tha...       3.236
# 15996       ja  It's depict Anne's growth from a girl to a wom...       3.558
# 15997       it                                                NaN       2.913
# 15998       ko                                                NaN       2.787
# 15999       en  A gameshow hosted by Alex & Laura filled with ...       2.485
#
#        vote_count  vote_average       budget      revenue
# 0            7449         6.380  165000000.0  752600867.0
# 1           37119         8.369  160000000.0  839030630.0
# 2           19327         7.744  250000000.0  954305868.0
# 3           11638         7.600  260000000.0  592461732.0
# 4           13259         7.800  165000000.0  494879471.0
# ...           ...           ...          ...          ...
# 15995           0         0.000          NaN          NaN
# 15996           0         0.000          NaN          NaN
# 15997           1        10.000          NaN          NaN
# 15998           0         0.000          NaN          NaN
# 15999           0         0.000          NaN          NaN
#
# [32000 rows x 18 columns]

# %%
df.info()
#Checking Number of Missing Values in each Row
missing_values=df.isnull().sum()
print('\n Missing Values:\n','\n',missing_values[missing_values>0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       32000 non-null  int64
#  1   type          32000 non-null  object
#  2   title         32000 non-null  object
#  3   director      20903 non-null  object
#  4   cast          30639 non-null  object
#  5   country       29737 non-null  object
#  6   date_added    32000 non-null  object
#  7   release_year  32000 non-null  int64
#  8   rating        32000 non-null  float64
#  9   duration      16000 non-null  object
#  10  genres        30919 non-null  object
#  11  language      32000 non-null  object
#  12  description   28662 non-null  object
#  13  popularity    32000 non-null  float64
#  14  vote_count    32000 non-null  int64
#  15  vote_average  32000 non-null  float64
#  16  budget        16000 non-null  float64
#  17  revenue       16000 non-null  float64
# dtypes: float64(5), int64(3), object(10)
# memory usage: 5.6+ MB
#
#  Missing Values:
#
#  director       11097
# cast            1361
# country         2263
# duration       16000
# genres          1081
# description     3338
# budget         16000
# revenue        16000
# dtype: int64

# %% [markdown]
# Here, 7 Columns are there which have Missing Values:
# director(object),
# cast(object),
# country(object),
# genre(object),
# description(object),
# budget(object),
# revenue(object),

# %% [markdown]
# *   **Duration data is only available for TV Show. for Movies These field is Missing.**
# *   **Budget and revenue data is only available for Movies. For TV
# Shows, these fields are missing.**

# %% [markdown]
# ## 🔹 Data Cleaning
# Steps performed:
# 1. Handle missing values
# 2. Convert `date_added` into datetime
# 3. Extract useful features (`year_added`, `content_age`)
# 4. Remove duplicates

# %%
df=df.drop(['season_num','movie_duration'],axis=1)

# %%
df.isnull().sum()

df.fillna({"director":"Unknown",'cast':"Unknown","country":"Unknown",'genres':"Unknown","description":"No Description Available"})

df['budget']=pd.to_numeric(df['budget'])

df['revenue']=pd.to_numeric(df['revenue'])

# %% [markdown]
# For TV Shows there are no such columns like revenue and budget. but in movies it is there.so there NaNs in tv shows.

# %%
profit=df['revenue']-df['budget']
ROI=profit/df['budget']
df['profit']=profit
df['ROI']=ROI
df.head(15)
# Out:
#     show_id   type                                         title  \
# 0     10192  Movie                           Shrek Forever After
# 1     27205  Movie                                     Inception
# 2     12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3     38757  Movie                                       Tangled
# 4     10191  Movie                      How to Train Your Dragon
# 5     11324  Movie                                Shutter Island
# 6     38575  Movie                                The Karate Kid
# 7     10138  Movie                                    Iron Man 2
# 8     38365  Movie                                     Grown Ups
# 9     48650  Movie                                  Room in Rome
# 10    20352  Movie                                 Despicable Me
# 11    10193  Movie                                   Toy Story 3
# 12    24021  Movie                    The Twilight Saga: Eclipse
# 13    12155  Movie                           Alice in Wonderland
# 14    73861  Movie                                A Serbian Film
#
#                        director  \
# 0                 Mike Mitchell
# 1             Christopher Nolan
# 2                   David Yates
# 3    Byron Howard, Nathan Greno
# 4   Chris Sanders, Dean DeBlois
# 5               Martin Scorsese
# 6                  Harald Zwart
# 7                   Jon Favreau
# 8                  Dennis Dugan
# 9                   Julio Medem
# 10  Pierre Coffin, Chris Renaud
# 11                  Lee Unkrich
# 12                  David Slade
# 13                   Tim Burton
# 14             Srđan Spasojević
#
#                                                  cast  \
# 0   Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1   Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2   Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3   Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4   Jay Baruchel, Gerard Butler, Craig Ferguson, A...
# 5   Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 6   Jaden Smith, Jackie Chan, Taraji P. Henson, We...
# 7   Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...
# 8   Adam Sandler, Kevin James, Chris Rock, David S...
# 9   Elena Anaya, Natasha Yarovenko, Enrico Lo Vers...
# 10  Steve Carell, Jason Segel, Miranda Cosgrove, E...
# 11  Tom Hanks, Tim Allen, Joan Cusack, Don Rickles...
# 12  Kristen Stewart, Robert Pattinson, Taylor Laut...
# 13  Mia Wasikowska, Johnny Depp, Anne Hathaway, He...
# 14  Srđan 'Žika' Todorović, Sergej Trifunović, Jel...
#
#                                        country  date_added  release_year  \
# 0                     United States of America  2010-05-16          2010
# 1     United Kingdom, United States of America  2010-07-15          2010
# 2     United Kingdom, United States of America  2010-11-17          2010
# 3                     United States of America  2010-11-24          2010
# 4                     United States of America  2010-03-18          2010
# 5                     United States of America  2010-02-14          2010
# 6   China, Hong Kong, United States of America  2010-06-10          2010
# 7                     United States of America  2010-04-28          2010
# 8                     United States of America  2010-06-24          2010
# 9                                France, Spain  2010-05-07          2010
# 10                    United States of America  2010-07-08          2010
# 11                    United States of America  2010-06-16          2010
# 12                    United States of America  2010-06-23          2010
# 13                    United States of America  2010-03-03          2010
# 14                                      Serbia  2010-06-16          2010
#
#     rating                                         genres language  \
# 0    6.380  Comedy, Adventure, Fantasy, Animation, Family       en
# 1    8.369             Action, Science Fiction, Adventure       en
# 2    7.744                             Adventure, Fantasy       en
# 3    7.600                   Animation, Family, Adventure       en
# 4    7.800          Fantasy, Adventure, Animation, Family       en
# 5    8.200                       Drama, Thriller, Mystery       en
# 6    6.500               Action, Adventure, Drama, Family       en
# 7    6.800             Adventure, Action, Science Fiction       en
# 8    6.394                                         Comedy       en
# 9    6.416                                 Drama, Romance       es
# 10   7.200                      Animation, Family, Comedy       en
# 11   7.800                      Animation, Family, Comedy       en
# 12   6.204             Adventure, Fantasy, Drama, Romance       en
# 13   6.600                     Family, Fantasy, Adventure       en
# 14   5.471                        Crime, Horror, Thriller       sr
#
#                                           description  popularity  vote_count  \
# 0   A bored and domesticated Shrek pacts with deal...     203.893        7449
# 1   Cobb, a skilled thief who commits corporate es...     156.242       37119
# 2   Harry, Ron and Hermione walk away from their l...     121.191       19327
# 3   Feisty teenager Rapunzel, who has long and mag...     111.762       11638
# 4   As the son of a Viking leader on the cusp of m...     110.044       13259
# 5   World War II soldier-turned-U.S. Marshal Teddy...     101.551       24282
# 6   Twelve-year-old Dre Parker could have been the...      96.385        6082
# 7   With the world now aware of his dual life as t...      95.255       21222
# 8   After their high school basketball coach passe...      93.281        6212
# 9   A hotel room in the center of Rome serves as t...      90.230         748
# 10  Villainous Gru lives up to his reputation as a...      86.361       15258
# 11  Woody, Buzz, and the rest of Andy's toys haven...      83.097       14847
# 12  Bella once again finds herself surrounded by d...      81.800        8829
# 13  Alice, now 19 years old, returns to the whimsi...      80.326       14114
# 14  Retired porn star Milos leads a normal family ...      74.238        2018
#
#     vote_average       budget       revenue       profit       ROI   loss
# 0          6.380  165000000.0  7.526009e+08  587600867.0  3.561217  False
# 1          8.369  160000000.0  8.390306e+08  679030630.0  4.243941  False
# 2          7.744  250000000.0  9.543059e+08  704305868.0  2.817223  False
# 3          7.600  260000000.0  5.924617e+08  332461732.0  1.278699  False
# 4          7.800  165000000.0  4.948795e+08  329879471.0  1.999270  False
# 5          8.200   80000000.0  2.948042e+08  214804195.0  2.685052  False
# 6          6.500   40000000.0  3.591260e+08  319126022.0  7.978151  False
# 7          6.800  200000000.0  6.239333e+08  423933331.0  2.119667  False
# 8          6.394   80000000.0  2.714302e+08  191430189.0  2.392877  False
# 9          6.416          0.0  8.442810e+05     844281.0       inf  False
# 10         7.200   69000000.0  5.432843e+08  474284256.0  6.873685  False
# 11         7.800  200000000.0  1.067316e+09  867316101.0  4.336581  False
# 12         6.204   68000000.0  6.984913e+08  630491347.0  9.271932  False
# 13         6.600  200000000.0  1.025467e+09  825467110.0  4.127336  False
# 14         5.471          0.0  0.000000e+00          0.0       NaN  False

# %%
df['ROI']=df['ROI'].replace([np.inf,-np.inf],np.nan)

# %% [markdown]
# **Profit and ROI apply only to Movies**
# **TV Shows:**

# %%
profit_mean=df['profit'].mean()
loss = df['profit']<0
df['loss']=loss

# %%
df[df['loss'] == True]
# Out:
#        show_id   type                        title  \
# 15       38234  Movie   Undisputed III: Redemption
# 34       22538  Movie  Scott Pilgrim vs. the World
# 37       43947  Movie         I Spit on Your Grave
# 43       46738  Movie                    Incendies
# 45       43949  Movie                      Flipped
# ...        ...    ...                          ...
# 15914  1439948  Movie                   Serlasanha
# 15922  1130863  Movie                        Belle
# 15959  1317288  Movie                Marty Supreme
# 15966  1282125  Movie            Delfino's Journey
# 15971  1424464  Movie                 Dollar Babys
#
#                            director  \
# 15                 Isaac Florentine
# 34                     Edgar Wright
# 37                 Steven R. Monroe
# 43                 Denis Villeneuve
# 45                       Rob Reiner
# ...                             ...
# 15914  Kelvin Bohn, Eduardo Wilborn
# 15922                Benoît Jacquot
# 15959                   Josh Safdie
# 15966        Arthur Allan Seidelman
# 15971     Remi Alfallah, Megan Haly
#
#                                                     cast  \
# 15     Scott Adkins, Mykel Shannon Jenkins, Mark Ivan...
# 34     Michael Cera, Mary Elizabeth Winstead, Ellen W...
# 37     Sarah Butler, Jeff Branson, Tracey Walter, And...
# 43     Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim...
# 45     Madeline Carroll, Callan McAuliffe, Rebecca De...
# ...                                                  ...
# 15914                                                NaN
# 15922  Charlotte Gainsbourg, Guillaume Canet, Pauline...
# 15959  Timothée Chalamet, Gwyneth Paltrow, Tyler, The...
# 15966  Fernando Paez, Julio Macias, Sal Lopez, Giovan...
# 15971  Shannon Haly, Kyra Green, Natasha Farkas, Mega...
#
#                                                country  date_added  \
# 15                            United States of America  2010-04-17
# 34     Japan, United Kingdom, United States of America  2010-08-12
# 37                            United States of America  2010-06-17
# 43                                      Canada, France  2010-09-17
# 45                            United States of America  2010-08-06
# ...                                                ...         ...
# 15914                                           Brazil  2025-02-27
# 15922                                  Belgium, France  2025-03-13
# 15959                Finland, United States of America  2025-12-25
# 15966                         United States of America  2025-04-10
# 15971                                              NaN  2025-02-25
#
#        release_year  rating duration  ... popularity vote_count vote_average  \
# 15             2010   7.517      NaN  ...     71.837        925        7.517
# 34             2010   7.491      NaN  ...     39.321       7985        7.491
# 37             2010   6.500      NaN  ...     38.125       2344        6.500
# 43             2010   8.100      NaN  ...     35.555       2830        8.100
# 45             2010   8.016      NaN  ...     34.886       3062        8.016
# ...             ...     ...      ...  ...        ...        ...          ...
# 15914          2025   0.000      NaN  ...      5.379          0        0.000
# 15922          2025   0.000      NaN  ...      5.296          0        0.000
# 15959          2025   0.000      NaN  ...      5.096          0        0.000
# 15966          2025   0.000      NaN  ...      5.067          0        0.000
# 15971          2025   0.000      NaN  ...      5.047          0        0.000
#
#            budget     revenue  season_num  movie_duration      profit  \
# 15      3000000.0    282548.0         NaN             NaN  -2717452.0
# 34     85000000.0  51691156.0         NaN             NaN -33308844.0
# 37      2000000.0    572809.0         NaN             NaN  -1427191.0
# 43      6800000.0   6788659.0         NaN             NaN    -11341.0
# 45     14000000.0   4324817.0         NaN             NaN  -9675183.0
# ...           ...         ...         ...             ...         ...
# 15914        17.0         0.0         NaN             NaN       -17.0
# 15922   3000000.0         0.0         NaN             NaN  -3000000.0
# 15959  70000000.0         0.0         NaN             NaN -70000000.0
# 15966   8600000.0         0.0         NaN             NaN  -8600000.0
# 15971        35.0         0.0         NaN             NaN       -35.0
#
#             ROI  loss
# 15    -0.905817  True
# 34    -0.391869  True
# 37    -0.713596  True
# 43    -0.001668  True
# 45    -0.691084  True
# ...         ...   ...
# 15914 -1.000000  True
# 15922 -1.000000  True
# 15959 -1.000000  True
# 15966 -1.000000  True
# 15971 -1.000000  True
#
# [2605 rows x 23 columns]

# %%
df_sorted=df.sort_values(by='release_year',ascending=False)
df_sorted.head(10)
# Out:
#        show_id     type                                   title  \
# 15999   251815  TV Show  Alex & Laura's Saturday Night Takeaway
# 15998   284613  TV Show                                 AI히치하이커
# 15997   284972  TV Show                     Le onde del passato
# 15996   277665  TV Show                            Anne Shirley
# 15995   284892  TV Show                              Sammelanam
# 15994   283934  TV Show                               Last Meal
# 15993   284894  TV Show                   Countrylandet Sverige
# 15992   284082  TV Show                                    Mine
# 15991   285141  TV Show                          BBB - Big Show
# 15990   273517  TV Show                        Everlasting Love
#
#                  director                                               cast  \
# 15999                 NaN                       Alex Bickerton, Lauren Blake
# 15998                 NaN                                                NaN
# 15997  Giulio Manfredonia  Anna Valle, Giorgio Marchesi, Irene Ferri, Fau...
# 15996                 NaN  Honoka Inoue, Yasunori Matsumoto, Aya Nakamura...
# 15995                 NaN                                                NaN
# 15994                 NaN             Duarte Correia da Silva, Nuno Mesquita
# 15993        Magnus Broni  Magnus Broni, Maja Francis, Hasse Andersson, J...
# 15992                 NaN        Zephanie Dimaranan, Josh Ford, Shan Vesagas
# 15991                 NaN                            Ana Clara Lima, Ed Gama
# 15990            Zhang Ao       Wu Jifeng, Wen Moyan, Liu Jiaxi, Yuan Ziming
#
#            country  date_added  release_year  rating   duration  ...  \
# 15999          NaN  2025-02-15          2025     0.0  1 Seasons  ...
# 15998          NaN  2025-02-16          2025     0.0  1 Seasons  ...
# 15997          NaN  2025-02-19          2025    10.0  1 Seasons  ...
# 15996        Japan  2025-04-05          2025     0.0  1 Seasons  ...
# 15995          NaN  2025-02-20          2025     0.0  1 Seasons  ...
# 15994          NaN  2025-01-27          2025     0.0  1 Seasons  ...
# 15993       Sweden  2025-02-21          2025     5.0  1 Seasons  ...
# 15992  Philippines  2025-02-14          2025     0.0  1 Seasons  ...
# 15991       Brazil  2025-01-20          2025     0.0  1 Seasons  ...
# 15990        China  2025-02-04          2025     0.0  1 Seasons  ...
#
#       popularity vote_count vote_average  budget  revenue  season_num  \
# 15999      2.485          0          0.0     NaN      NaN         1.0
# 15998      2.787          0          0.0     NaN      NaN         1.0
# 15997      2.913          1         10.0     NaN      NaN         1.0
# 15996      3.558          0          0.0     NaN      NaN         1.0
# 15995      3.236          0          0.0     NaN      NaN         1.0
# 15994      3.073          0          0.0     NaN      NaN         1.0
# 15993      2.418          1          5.0     NaN      NaN         1.0
# 15992      2.487          0          0.0     NaN      NaN         1.0
# 15991      3.075          0          0.0     NaN      NaN         1.0
# 15990      2.622          0          0.0     NaN      NaN         1.0
#
#        movie_duration  profit  ROI   loss
# 15999             NaN     NaN  NaN  False
# 15998             NaN     NaN  NaN  False
# 15997             NaN     NaN  NaN  False
# 15996             NaN     NaN  NaN  False
# 15995             NaN     NaN  NaN  False
# 15994             NaN     NaN  NaN  False
# 15993             NaN     NaN  NaN  False
# 15992             NaN     NaN  NaN  False
# 15991             NaN     NaN  NaN  False
# 15990             NaN     NaN  NaN  False
#
# [10 rows x 23 columns]

# %%
# !git config --global user.email "pankajbarathod9@gmail.com"
# !git config --global user.name "Krishna3226"

# %%
# !git add "Netflix_EDA.ipynb"
# !git commit -m "Updated Netflix analysis with new cleaning steps"
# !git push origin main
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add "Netflix_EDA.ipynb"
# !git commit -m "Cleaned Data, Dropped Duration Column and Sorted data Year-Wise."
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
